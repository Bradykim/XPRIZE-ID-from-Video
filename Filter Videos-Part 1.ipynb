# %%
#RUN THIS FIRST!!!!!!!!!
# !pip install opencv-python
# !pip install google-cloud-vision
# Out:
# Requirement already satisfied: opencv-python in c:\users\brady\anaconda3\lib\site-packages (4.5.3.56)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\brady\anaconda3\lib\site-packages (from opencv-python) (1.19.2)
# Requirement already satisfied: google-cloud-vision in c:\users\brady\anaconda3\lib\site-packages (2.4.4)
# Requirement already satisfied: packaging>=14.3 in c:\users\brady\anaconda3\lib\site-packages (from google-cloud-vision) (20.4)
# Requirement already satisfied: google-api-core[grpc]<3.0.0dev,>=1.26.0 in c:\users\brady\anaconda3\lib\site-packages (from google-cloud-vision) (2.0.1)
# Requirement already satisfied: proto-plus>=1.15.0 in c:\users\brady\anaconda3\lib\site-packages (from google-cloud-vision) (1.19.2)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\brady\anaconda3\lib\site-packages (from packaging>=14.3->google-cloud-vision) (2.4.7)
# Requirement already satisfied: six in c:\users\brady\anaconda3\lib\site-packages (from packaging>=14.3->google-cloud-vision) (1.15.0)
# Requirement already satisfied: protobuf>=3.12.0 in c:\users\brady\anaconda3\lib\site-packages (from google-api-core[grpc]<3.0.0dev,>=1.26.0->google-cloud-vision) (3.18.0)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in c:\users\brady\anaconda3\lib\site-packages (from google-api-core[grpc]<3.0.0dev,>=1.26.0->google-cloud-vision) (2.24.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in c:\users\brady\anaconda3\lib\site-packages (from google-api-core[grpc]<3.0.0dev,>=1.26.0->google-cloud-vision) (1.53.0)
# Requirement already satisfied: google-auth<3.0dev,>=1.25.0 in c:\users\brady\anaconda3\lib\site-packages (from google-api-core[grpc]<3.0.0dev,>=1.26.0->google-cloud-vision) (2.2.1)
# Requirement already satisfied: setuptools>=40.3.0 in c:\users\brady\anaconda3\lib\site-packages (from google-api-core[grpc]<3.0.0dev,>=1.26.0->google-cloud-vision) (50.3.1.post20201107)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2; extra == "grpc" in c:\users\brady\anaconda3\lib\site-packages (from google-api-core[grpc]<3.0.0dev,>=1.26.0->google-cloud-vision) (1.41.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\brady\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<3.0.0dev,>=1.26.0->google-cloud-vision) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\brady\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<3.0.0dev,>=1.26.0->google-cloud-vision) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\brady\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<3.0.0dev,>=1.26.0->google-cloud-vision) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\brady\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<3.0.0dev,>=1.26.0->google-cloud-vision) (2.10)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\brady\anaconda3\lib\site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]<3.0.0dev,>=1.26.0->google-cloud-vision) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\brady\anaconda3\lib\site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]<3.0.0dev,>=1.26.0->google-cloud-vision) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\brady\anaconda3\lib\site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]<3.0.0dev,>=1.26.0->google-cloud-vision) (4.2.4)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\brady\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=1.25.0->google-api-core[grpc]<3.0.0dev,>=1.26.0->google-cloud-vision) (0.4.8)

# %%
import io
import os
import cv2
import glob
import requests
import json


os.environ["GOOGLE_APPLICATION_CREDENTIALS"]="ocean-engineering-96e0c62d5fe3.json"
# Imports the Google Cloud client library
from google.cloud import vision
from google.cloud.vision_v1 import types


def distanceCalc(pic_1,pic_2):
    r = requests.post(
        "https://api.deepai.org/api/image-similarity",
        files={
            'image1': open(pic_1, 'rb'),
            'image2': open(pic_2, 'rb'),
        },
        headers={'api-key': '7e7d3b99-2106-4b27-9ef4-9e3e2fccf04b'} #NEED A UNIQUE API KEY!!!!!!!!!!!!!!!!!!!
        )
    distanceDict = r.json()
    
    distance = distanceDict['output']["distance"]
    distance = int(distance)
    
    
    return distance

# fps of video to frames
fps = 20

# Threshold of frame score
threshold1 = 0.80
threshold2 = 0.9

# Read all videos
path1 = 'input'
#path2 = 'output1'
vidnum = 0
for video in glob.glob(os.path.join(path1, '*.[mM][pP]4')):
    # Path to video file
    vidObj = cv2.VideoCapture(video)

    # Used as counter variable
    count = 0

    # Checks whether frames were extracted
    success = 1

    while success:
        # vidObj object calls read
        # function extract frames
        success, image = vidObj.read()

        if not success:
            break


        if count % fps == 0:
            # Saves the frames with num
            num = count
            realcount = count/20
            cv2.imwrite("output1/video" + str(vidnum) +
                        "frame%d.jpg" % realcount, image)

        count += 1

    vidnum += 1

# Instantiates a client
client = vision.ImageAnnotatorClient()

# Read all frames
path2 = 'output1'
picture_list = []
for frame in glob.glob(os.path.join(path2, '*.jpg')):
    # The name of the image file to annotate
    file_name = os.path.abspath(frame)

    # Loads the image into memory
    with io.open(file_name, 'rb') as image_file:
        content = image_file.read()

    image = types.Image(content=content)

    # Performs label detection on the image file
    response = client.label_detection(image=image)
    labels = response.label_annotations

    
    
    # Step 1: Remove unqualified frames
    score = 0
    max_score = 0
    max_label = ''
    for label in labels:
        score = label.score
        if score > threshold1:
            max_score = max(score,max_score)
            #Error is right here
            if max_score == score:
                max_label = label
            
            print("Score for " + frame + ": "+ "with "+label.description+ ":"+ str(score))
        
    if max_score < threshold2:
        os.remove(frame)
        print("---------DELETED---------")

    else:
        picture_list.append([file_name, max_label.description, max_score])
    print("---------------------------------------------------------------------")
    
#We want to delete if similarity checker returns value greater than 30 and top label is the same
#Step 2: Checks similarity of two images to each other



index = 0

while (index < len(picture_list)-1 and len(picture_list) > 1):
    
    pic_1 = picture_list[index]
    pic_2 = picture_list[index+1]
    print(pic_1[1])
    print(pic_1[2])
    print(pic_2[1])
    print(pic_2[2])
    distance = distanceCalc(pic_1[0],pic_2[0])

    
    if (distance <=20 and (pic_1[1] == pic_2[1])) :
        print("Deleting Image")
        if pic_1[2] < pic_2[2]:
            os.remove(pic_1[0])
            picture_list.remove(pic_1)
        else:
            os.remove(pic_2[0])
            picture_list.remove(pic_2)
    else:
        index += 1
# Out:
# Score for output1\video0frame0.jpg: with Dog:0.9350937008857727
# Score for output1\video0frame0.jpg: with Carnivore:0.8658835887908936
# Score for output1\video0frame0.jpg: with Plant:0.8571410179138184
# Score for output1\video0frame0.jpg: with Grass:0.8490780591964722
# Score for output1\video0frame0.jpg: with Water dog:0.8379926681518555
# Score for output1\video0frame0.jpg: with Dog breed:0.8241424560546875
# Score for output1\video0frame0.jpg: with Fawn:0.8150314688682556
# Score for output1\video0frame0.jpg: with Companion dog:0.8097087144851685
# ---------------------------------------------------------------------
# Score for output1\video0frame1.jpg: with Vertebrate:0.9226320385932922
# Score for output1\video0frame1.jpg: with Green:0.9064102172851562
# Score for output1\video0frame1.jpg: with Plant:0.9046342372894287
# Score for output1\video0frame1.jpg: with Natural environment:0.8917385339736938
# Score for output1\video0frame1.jpg: with People in nature:0.887840747833252
# Score for output1\video0frame1.jpg: with Botany:0.877533495426178
# Score for output1\video0frame1.jpg: with Vegetation:0.860889196395874
# Score for output1\video0frame1.jpg: with Mammal:0.8579336404800415
# Score for output1\video0frame1.jpg: with Grass:0.8371612429618835
# Score for output1\video0frame1.jpg: with Woody plant:0.803852915763855
# ---------------------------------------------------------------------
# Score for output1\video0frame10.jpg: with Plant:0.9613170027732849
# Score for output1\video0frame10.jpg: with Dog:0.935083270072937
# Score for output1\video0frame10.jpg: with Carnivore:0.8538975119590759
# Score for output1\video0frame10.jpg: with Tree:0.848348081111908
# Score for output1\video0frame10.jpg: with Grass:0.8429985046386719
# ---------------------------------------------------------------------
# Score for output1\video0frame11.jpg: with Plant:0.9623689651489258
# Score for output1\video0frame11.jpg: with Tree:0.8509669303894043
# Score for output1\video0frame11.jpg: with Dog:0.8431588411331177
# Score for output1\video0frame11.jpg: with Grass:0.8336971402168274
# Score for output1\video0frame11.jpg: with Carnivore:0.8039906620979309
# ---------------------------------------------------------------------
# Score for output1\video0frame12.jpg: with Plant:0.952353835105896
# Score for output1\video0frame12.jpg: with Leaf:0.8950097560882568
# Score for output1\video0frame12.jpg: with Land lot:0.8462876677513123
# Score for output1\video0frame12.jpg: with Grass:0.8373361229896545
# Score for output1\video0frame12.jpg: with Tree:0.8219960331916809
# ---------------------------------------------------------------------
# Score for output1\video0frame13.jpg: with Plant:0.9513209462165833
# Score for output1\video0frame13.jpg: with Dog:0.8596756458282471
# Score for output1\video0frame13.jpg: with Mammal:0.8548771142959595
# Score for output1\video0frame13.jpg: with Land lot:0.8490651845932007
# Score for output1\video0frame13.jpg: with Grass:0.8357160687446594
# Score for output1\video0frame13.jpg: with Tree:0.828812837600708
# ---------------------------------------------------------------------
# Score for output1\video0frame14.jpg: with Plant:0.9594573974609375
# Score for output1\video0frame14.jpg: with Dog:0.9004292488098145
# Score for output1\video0frame14.jpg: with Tree:0.8570474982261658
# Score for output1\video0frame14.jpg: with Mammal:0.8538509011268616
# Score for output1\video0frame14.jpg: with Land lot:0.8508617281913757
# Score for output1\video0frame14.jpg: with Grass:0.8454636335372925
# Score for output1\video0frame14.jpg: with Carnivore:0.801078200340271
# ---------------------------------------------------------------------
# Score for output1\video0frame15.jpg: with Plant:0.9565430879592896
# Score for output1\video0frame15.jpg: with Dog:0.8643891215324402
# Score for output1\video0frame15.jpg: with Land lot:0.8496626019477844
# Score for output1\video0frame15.jpg: with Tree:0.848578929901123
# Score for output1\video0frame15.jpg: with Grass:0.8299907445907593
# Score for output1\video0frame15.jpg: with Carnivore:0.8257858157157898
# ---------------------------------------------------------------------
# Score for output1\video0frame16.jpg: with Plant:0.9614043831825256
# Score for output1\video0frame16.jpg: with Grass:0.8310432434082031
# Score for output1\video0frame16.jpg: with Tree:0.8210321664810181
# ---------------------------------------------------------------------
# Score for output1\video0frame2.jpg: with Plant:0.9465910792350769
# Score for output1\video0frame2.jpg: with People in nature:0.8853396773338318
# Score for output1\video0frame2.jpg: with Flower:0.8809633851051331
# Score for output1\video0frame2.jpg: with Botany:0.8709796071052551
# Score for output1\video0frame2.jpg: with Grass:0.8301533460617065
# ---------------------------------------------------------------------
# Score for output1\video0frame3.jpg: with Plant:0.9603845477104187
# Score for output1\video0frame3.jpg: with Flower:0.9427255988121033
# Score for output1\video0frame3.jpg: with People in nature:0.8997951149940491
# Score for output1\video0frame3.jpg: with Vegetation:0.8521860837936401
# Score for output1\video0frame3.jpg: with Grass:0.8323212265968323
# ---------------------------------------------------------------------
# Score for output1\video0frame4.jpg: with Plant:0.9562150835990906
# Score for output1\video0frame4.jpg: with Green:0.897064208984375
# Score for output1\video0frame4.jpg: with People in nature:0.8955693244934082
# Score for output1\video0frame4.jpg: with Grass:0.8451496958732605
# Score for output1\video0frame4.jpg: with Tree:0.8135302662849426
# Score for output1\video0frame4.jpg: with Dog:0.8017327785491943
# ---------------------------------------------------------------------
# Score for output1\video0frame5.jpg: with Plant:0.951068639755249
# Score for output1\video0frame5.jpg: with Dog:0.9493228197097778
# Score for output1\video0frame5.jpg: with Leaf:0.8938543200492859
# Score for output1\video0frame5.jpg: with People in nature:0.8803470730781555
# Score for output1\video0frame5.jpg: with Tree:0.846714437007904
# Score for output1\video0frame5.jpg: with Grass:0.8381267786026001
# Score for output1\video0frame5.jpg: with Carnivore:0.8347730040550232
# ---------------------------------------------------------------------
# Score for output1\video0frame6.jpg: with Plant:0.9572929739952087
# Score for output1\video0frame6.jpg: with Dog:0.9496008157730103
# Score for output1\video0frame6.jpg: with Green:0.9043344855308533
# Score for output1\video0frame6.jpg: with People in nature:0.8608438968658447
# Score for output1\video0frame6.jpg: with Grass:0.8539066910743713
# Score for output1\video0frame6.jpg: with Carnivore:0.8406422138214111
# Score for output1\video0frame6.jpg: with Fawn:0.8150418400764465
# ---------------------------------------------------------------------
# Score for output1\video0frame7.jpg: with Plant:0.9337136149406433
# Score for output1\video0frame7.jpg: with Leaf:0.8936829566955566
# Score for output1\video0frame7.jpg: with Dog:0.8703290820121765
# Score for output1\video0frame7.jpg: with People in nature:0.8442313075065613
# Score for output1\video0frame7.jpg: with Grass:0.8294636011123657
# Score for output1\video0frame7.jpg: with Carnivore:0.8293551802635193
# ---------------------------------------------------------------------
# Score for output1\video0frame8.jpg: with Plant:0.941259503364563
# Score for output1\video0frame8.jpg: with Dog:0.9212920665740967
# Score for output1\video0frame8.jpg: with Leaf:0.8931070566177368
# Score for output1\video0frame8.jpg: with People in nature:0.8453114032745361
# Score for output1\video0frame8.jpg: with Tree:0.8437654376029968
# Score for output1\video0frame8.jpg: with Natural landscape:0.8378904461860657
# Score for output1\video0frame8.jpg: with Carnivore:0.8178951740264893
# Score for output1\video0frame8.jpg: with Grass:0.813729465007782
# ---------------------------------------------------------------------
# Score for output1\video0frame9.jpg: with Plant:0.9568797945976257
# Score for output1\video0frame9.jpg: with Dog:0.9336672425270081
# Score for output1\video0frame9.jpg: with Window:0.8819712996482849
# Score for output1\video0frame9.jpg: with Carnivore:0.8516238331794739
# Score for output1\video0frame9.jpg: with Grass:0.8441800475120544
# Score for output1\video0frame9.jpg: with Tree:0.8359169363975525
# ---------------------------------------------------------------------
# Dog
# 0.9350937008857727
# Vertebrate
# 0.9226320385932922
# Vertebrate
# 0.9226320385932922
# Plant
# 0.9613170027732849
# Plant
# 0.9613170027732849
# Plant
# 0.9623689651489258
# Deleting Image
# Plant
# 0.9623689651489258
# Plant
# 0.952353835105896
# Plant
# 0.952353835105896
# Plant
# 0.9513209462165833
# Deleting Image
# Plant
# 0.952353835105896
# Plant
# 0.9594573974609375
# Deleting Image
# Plant
# 0.9594573974609375
# Plant
# 0.9565430879592896
# Deleting Image
# Plant
# 0.9594573974609375
# Plant
# 0.9614043831825256
# Deleting Image
# Plant
# 0.9614043831825256
# Plant
# 0.9465910792350769
# Plant
# 0.9465910792350769
# Plant
# 0.9603845477104187
# Deleting Image
# Plant
# 0.9603845477104187
# Plant
# 0.9562150835990906
# Deleting Image
# Plant
# 0.9603845477104187
# Plant
# 0.951068639755249
# Deleting Image
# Plant
# 0.9603845477104187
# Plant
# 0.9572929739952087
# Deleting Image
# Plant
# 0.9603845477104187
# Plant
# 0.9337136149406433
# Plant
# 0.9337136149406433
# Plant
# 0.941259503364563
# Plant
# 0.941259503364563
# Plant
# 0.9568797945976257
